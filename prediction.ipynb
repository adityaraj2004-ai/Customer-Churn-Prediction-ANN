# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import load_model
import pickle

# %%
# Loading all the trained model, scaler pickle file, onehot encoder pickle file
model = load_model('model.h5')
